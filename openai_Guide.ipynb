# %%
# pip install openai

# %%
pip install python-dotenv
# Out:
# Requirement already satisfied: python-dotenv in c:\Users\Ranjit\AppData\Local\Programs\Python\Python312\Lib\site-packages (1.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from openai import OpenAI
from dotenv import load_dotenv 
import os 
load_dotenv()
# Out:
# True

# %%
api_ky = os.getenv("OPENAI_API_KEY")
client = OpenAI(api_key=api_ky)

# %%
response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "system", "content": "You are a helpful assistant"},
        {"role": "user", "content": "Who is the prime minister of India?"}
    ]
)

print(response.choices[0].message.content)
# Out:
# As of my last update in October 2023, the Prime Minister of India is Narendra Modi. He has been in office since May 26, 2014. Please verify with up-to-date sources as political positions can change.

# %%
query = input("Plz ask something  : ")
response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "system", "content": "You are a helpful assistant"},
        {"role": "user", "content": query}
    ],
    max_tokens=50,
)

print(response.choices[0].message.content)

# %%
# prompt to pass the input text + image(internet)
prompt = [
        {
            "role": "user",
            "content": [
                {"type": "text", "text": "what's in this image?"},
                {
                    "type": "image_url",
                    "image_url": {
                        "url": "https://api.nga.gov/iiif/a2e6da57-3cd1-4235-b20e-95dcaefed6c8/full/!800,800/0/default.jpg"
                    }
                }
            ]
        }
    ]

# %%
# prompt to pass the input text + image(local)
prompt = [
        {
            "role": "user",
            "content": [
                {"type": "text", "text": "what's in this image?"},
                {
                    "type": "image_url",
                    "image_url": {
                        "url": f"data:image/jpeg;base64,{image_in_base64}"
                    }
                }
            ]
        }
    ]

# %% [markdown]
# #### Multimodel list
# <ul>
# <li>gpt-4o-mini</li>
# <li>gpt-4.1-mini</li>
# </ul>

# %%
# pip install openai

# %%
from openai import OpenAI
from dotenv import load_dotenv
import os 
load_dotenv()
# Out:
# False

# %%
apikey = os.getenv("OPENAI_API_KEY")
client = OpenAI(api_key=apikey)

# %%
response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "system", "content": "You are a helpful assistant"},
        {"role": "user", "content": "Who is the prime minister of India?"}
    ]
)

print(response.choices[0].message.content)
# Out:
# As of my last knowledge update in October 2023, the Prime Minister of India is Narendra Modi. He has been in office since May 26, 2014. Please verify with current sources to ensure this information is still accurate.

# %%
stream = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "system", "content": "You are a helpful assistant"},
        {"role": "user", "content": "Write 10 line of poem"}
    ],
    stream=True
)

for chunk in stream:
    print(chunk.choices[0].delta.content,end="")
# Out:
# In the hush of dawn where shadows play,
# Whispers of dreams greet the breaking day.
# Golden rays dance on the silent stream,
# Waking the world from its slumbering dream.
#
# Leaves rustle softly in the gentle breeze,
# Nature's melodies stir the ancient trees.
# Each petal unfurling, a story untold,
# In colors of crimson, and marigold.
#
# Time drifts like clouds in the vast, endless sky,
# Embracing the moment—here, we learn to fly.  None

# %%
response = client.chat.completions.create(
    model="gpt-4.1-mini",
    messages=[
        {
            "role": "user",
            "content": [
                {"type": "text", "text": "what you can see in this image?"},
                {
                    "type": "image_url",
                    "image_url": {
                        "url": "https://api.nga.gov/iiif/a2e6da57-3cd1-4235-b20e-95dcaefed6c8/full/!800,800/0/default.jpg"
                    }
                }
            ]
        }
    ]
)

print(response.choices[0].message.content)
# Out:
# This image depicts a painting of a seated woman. She is wearing a red and blue striped dress with orange buttons down the front and a blue skirt with orange polka dots. She has a red ribbon tied in her hair, which is pulled back. The woman holds a small bouquet of flowers in her left hand, resting on her lap. The background is a textured plain light blue or pale green color, and she is sitting on a dark wooden chair with curved arms. The painting style involves visible brushstrokes and a combination of bold colors, suggesting it might be from an artist with an expressive, post-impressionist style.

# %%
## image that present on your local 

import base64 

with open("rag_process.PNG","rb") as file:
    image_in_base64 = base64.b64encode(file.read()).decode("utf-8")

    
response = client.chat.completions.create(
    model="gpt-4.1-mini",
    messages=[
        {
            "role": "user",
            "content": [
                {"type": "text", "text": "tell me, how many steps are showing in this RAG process?"},
                {
                    "type": "image_url",
                    "image_url": {
                        "url": f"data:image/jpeg;base64,{image_in_base64}"   # data:<file type>;base64,<encoded data>
                    }
                }
            ]
        }
    ]
)

print(response.choices[0].message.content)
# Out:
# The RAG process shown in the image consists of 8 steps:
#
# 1. Documents Added to Knowledge Base
# 2. Split into Chunks
# 3. Create Embeddings
# 4. Store in Vector DB
# 5. User Asks Question
# 6. Retrieve Relevant Chunks
# 7. Send Chunks to LLM
# 8. Generate Answer

# %%
## image that present on your local 

import base64 

with open("rag_process.PNG","rb") as file:
    image_in_base64 = base64.b64encode(file.read()).decode("utf-8")

    
response = client.chat.completions.create(
    model="gpt-4.1-mini",
    messages=[
        {
            "role": "user",
            "content": [
                {"type": "text", "text": "how many circles in this image?"},
                {
                    "type": "image_url",
                    "image_url": {
                        "url": f"data:image/jpeg;base64,{image_in_base64}"   # data:<file type>;base64,<encoded data>
                    }
                }
            ]
        }
    ]
)

print(response.choices[0].message.content)
# Out:
# There are 16 circles in the image.

# %%
image_text_prompt = """
An Indian husband and wife sitting together on a traditional charpai (cot) in the middle of a mustard field, surrounded by blooming yellow flowers.
The husband has a well-groomed beard and mustache, with a lean build around 54kg, wearing a casual kurta-pajama. The wife is around 49kg,
wearing a colorful traditional saree with bangles, bindi, and a gentle smile. Both look happy and relaxed,
enjoying the serene countryside. The scene is set during golden hour in the evening, with soft warm sunlight casting a golden glow over the field.
The background features rural India scenery with natural greenery and a peaceful ambiance"""

result = client.images.generate(
    model="dall-e-3",
    prompt=image_text_prompt,
    n=1,
    size="1024x1024"
)
image_url = result.data[0].url
print(image_url)
# Out:
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-7J3I8g0JRqCYqf9X3Er24HbU/user-VqjyE2UCb5a2g2iJwal0zhPN/img-9jEye4Xuivb2X23k3dSesFfU.png?st=2026-03-18T13%3A57%3A59Z&se=2026-03-18T15%3A57%3A59Z&sp=r&sv=2026-02-06&sr=b&rscd=inline&rsct=image/png&skoid=475fd488-6c59-44a5-9aa9-31c4db451bea&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2026-03-17T17%3A51%3A18Z&ske=2026-03-18T17%3A51%3A18Z&sks=b&skv=2026-02-06&sig=4STnHs%2B17cxk6icZbie6y/2WGJycZ2ffp%2BNQQzKZ2Sc%3D

# %%
### Download the image 
import requests

response = requests.get(image_url)

with open("generated_image.png", "wb") as f:
    f.write(response.content)
    print("Your image is saved!")
# Out:
# Your image is saved!
