# %%
print("hello wolrd")  # ctrl + enter
# Out:
# hello wolrd

# %% [markdown]
# ### Variable

# %%
## variable bucket 
x = 5   # x = variable 
# asignment operator 
y = 5 
z = x + y 
print(z)
# Out:
# 10

# %%
x = 5 
X = 10 
print(X)
# Out:
# 10

# %%
# case  sensitive 
age  = 25 
Age = 26 
print(Age)
# Out:
# 26

# %%
a-z and A-Z and _ and 0-9

# %%
h@ = 5 
print(h@)
# Out:
#   Cell In[7], line 1
#     h@ = 5
#        ^
# SyntaxError: invalid syntax

# %%
h = 5 
print(h)
# Out:
# 5

# %%
1a = 5 
print(1a)
# Out:
#   Cell In[9], line 1
#     1a = 5
#     ^
# SyntaxError: invalid decimal literal

# %%
nu2m1 = 14 
print(nu2m1)
# Out:
# 14

# %%
## data types : 
int x = 10 ;

# %%
x = 10 
print(x)
print(type(x))
# Out:
# 10
# <class 'int'>

# %%
# int : value without decimal (4 byte )

# %%
x = 10.5 
print(x)
print(type(x))
# Out:
# 10.5
# <class 'float'>

# %%
#float : it is a numerical value with decimal

# %%
# boolean  True/ false 
x = False 
print(x)
print(type(x))
# Out:
# False
# <class 'bool'>

# %% [markdown]
# ### String

# %%
st = "Techie solution 1255"
print(st)
print(type(st))
# Out:
# Techie solution 1255
# <class 'str'>

# %%
st = "SOLUTION" 
print(st)
print(st[2])
print(st[2:6])
print(st[1:4])
# Out:
# SOLUTION
# L
# LUTI
# OLU

# %%
st = "TECHIE SOLUTION"
print(st)
print(len(st))
print(st[4:9])
# Out:
# TECHIE SOLUTION
# 15
# IE SO

# %%
st = "SOLUTION"
print(st[1:6:3])
# Out:
# OT

# %%
st = "SOL UTI  ON" 
print(st[:4])
print(st[:])
print(len(st))

print(st.count("U"))
# Out:
# SOL
# SOL UTI  ON
# 11
# 1

# %%
st = " PYTHON 
dfkdfd dfdf 
dfdfdlfj 
dfdfdkfsf dkfskfsk djfls
dgdkd eifnls """
print(st) 
print(type(st))
# Out:
#  PYTHON
# dfkdfd dfdf
# dfdfdlfj
# dfdfdkfsf dkfskfsk djfls
# dgdkd eifnls
# <class 'str'>

# %% [markdown]
# #### String

# %% [markdown]
# ### List
