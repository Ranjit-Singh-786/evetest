# %%
import pandas as pd 
df = pd.read_csv(r"Used_Bikes_data.csv")

# %%
df.head()
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#          owner  age  power          brand
# 0  First Owner  3.0  110.0            TVS
# 1  First Owner  4.0  350.0  Royal Enfield
# 2  First Owner  8.0  675.0        Triumph
# 3  First Owner  4.0  180.0            TVS
# 4  First Owner  3.0  150.0         Yamaha

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32648 entries, 0 to 32647
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   bike_name   32648 non-null  object
#  1   price       32648 non-null  float64
#  2   city        32648 non-null  object
#  3   kms_driven  32648 non-null  float64
#  4   owner       32648 non-null  object
#  5   age         32648 non-null  float64
#  6   power       32648 non-null  float64
#  7   brand       32648 non-null  object
# dtypes: float64(4), object(4)
# memory usage: 2.0+ MB

# %%
df.duplicated().sum()
# Out:
# 25324

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (7324, 8)

# %%
df.head()
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#          owner  age  power          brand
# 0  First Owner  3.0  110.0            TVS
# 1  First Owner  4.0  350.0  Royal Enfield
# 2  First Owner  8.0  675.0        Triumph
# 3  First Owner  4.0  180.0            TVS
# 4  First Owner  3.0  150.0         Yamaha

# %%
delhi = df[(df['city'] == "Delhi") & (df['brand']=="Royal Enfield")]
delhi.shape
# Out:
# (305, 8)

# %%
df["brand"].value_counts().keys()
# Out:
# Index(['Bajaj', 'Royal Enfield', 'Hero', 'Honda', 'Yamaha', 'TVS', 'KTM',
#        'Suzuki', 'Harley-Davidson', 'Kawasaki', 'Hyosung', 'Mahindra',
#        'Benelli', 'Triumph', 'Ducati', 'BMW', 'Jawa', 'Indian', 'MV',
#        'Rajdoot', 'LML', 'Yezdi', 'Ideal'],
#       dtype='object', name='brand')

# %%
brands = ['Bajaj', 'Royal Enfield', 'Hero', 'Honda', 'Yamaha', 'TVS', 'KTM',
       'Suzuki', 'Harley-Davidson', 'Kawasaki', 'Hyosung', 'Mahindra',
       'Benelli', 'Triumph', 'Ducati', 'BMW']

df2 = df[df['brand'].isin(brands)]
df2.head()
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#          owner  age  power          brand
# 0  First Owner  3.0  110.0            TVS
# 1  First Owner  4.0  350.0  Royal Enfield
# 2  First Owner  8.0  675.0        Triumph
# 3  First Owner  4.0  180.0            TVS
# 4  First Owner  3.0  150.0         Yamaha

# %%
df['brand'].nunique()
# Out:
# 23

# %%
df2['city'].nunique()
# Out:
# 443

# %%
df2['city'].unique()
# Out:
# array(['Ahmedabad', 'Delhi', 'Bangalore', 'Mumbai', 'Kalyan', 'Faridabad',
#        'Mettur', 'Hyderabad', 'Kaithal', 'Gurgaon', 'Pune', 'Noida',
#        'Nashik', 'Kochi', 'Allahabad', 'Samastipur', 'Nadiad', 'Lucknow',
#        'Jaipur', 'Karnal', 'Gorakhpur', 'Vidisha', 'Hosur', 'Bagalkot',
#        'Baripara', 'Agra', 'Dharwad', 'Vadodara', 'Jalandhar', 'Surat',
#        'Chennai', 'Navi Mumbai', 'Gandhidham', 'Visakhapatnam',
#        'Thrissur', 'Kolkata', 'Ernakulam', 'Barasat', 'Ghaziabad',
#        'Bhubaneshwar', 'Amritsar', 'Bhopal', 'Hamirpur(hp)', 'Kottayam',
#        'Arrah', 'Patiala', 'Ranga Reddy', 'Mandi', 'Ludhiana', 'Mandya',
#        'Siliguri', 'Aurangabad', 'Kanpur', 'Bhilwara', 'Meerut', 'Rewari',
#        'Ahmednagar', 'Wardha', 'Chandigarh', 'Ranchi', 'Panvel', 'Thane',
#        'Jabalpur', 'Kota', 'Rohtak', 'Rajkot', 'Varanasi', '24 Pargana',
#        'Banka', 'Nagpur', 'Banki', 'Pali', 'Chhatarpur', 'Katihar',
# ...

# %%
df["owner"].value_counts()
# Out:
# owner
# First Owner             6642
# Second Owner             588
# Third Owner               84
# Fourth Owner Or More      10
# Name: count, dtype: int64

# %%
delhi['price'].min()
# Out:
# 33500.0

# %%
delhi[delhi['price'] == delhi['price'].min()]
# Out:
#                             bike_name    price   city  kms_driven  \
# 5811  Royal Enfield Thunderbird 350cc  33500.0  Delhi     49463.0
#
#             owner   age  power          brand
# 5811  First Owner  16.0  350.0  Royal Enfield

# %%
delhi["owner"].value_counts()
# Out:
# owner
# First Owner             268
# Second Owner             33
# Fourth Owner Or More      2
# Third Owner               2
# Name: count, dtype: int64

# %%
test = delhi[delhi['price'] <= delhi['price'].mean()]
test.head()
# Out:
#                                     bike_name    price   city  kms_driven  \
# 9    Royal Enfield Classic Desert Storm 500cc  88000.0  Delhi     19000.0
# 44                Royal Enfield Classic 350cc  85000.0  Delhi     18000.0
# 51                Royal Enfield‎ Bullet 350cc  90000.0  Delhi     15300.0
# 64            Royal Enfield Thunderbird 350cc  88000.0  Delhi     19000.0
# 126               Royal Enfield Classic 350cc  92500.0  Delhi     11000.0
#
#             owner  age  power          brand
# 9    Second Owner  7.0  500.0  Royal Enfield
# 44    First Owner  6.0  350.0  Royal Enfield
# 51    First Owner  7.0  350.0  Royal Enfield
# 64    First Owner  5.0  350.0  Royal Enfield
# 126   First Owner  6.0  350.0  Royal Enfield

# %%
test['owner'].value_counts()
# Out:
# owner
# First Owner             135
# Second Owner             29
# Fourth Owner Or More      2
# Third Owner               2
# Name: count, dtype: int64

# %%
# pip install matplotlib

# %%
df.head()
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#          owner  age  power          brand
# 0  First Owner  3.0  110.0            TVS
# 1  First Owner  4.0  350.0  Royal Enfield
# 2  First Owner  8.0  675.0        Triumph
# 3  First Owner  4.0  180.0            TVS
# 4  First Owner  3.0  150.0         Yamaha

# %%
city_record = ['Ahmedabad', 'Bangalore' , 'Hyderabad' ]
df[df['city'].isin(city_record)]["city"].value_counts()
# Out:
# city
# Bangalore    683
# Ahmedabad    249
# Hyderabad    239
# Name: count, dtype: int64

# %%
city = list(df[df['city'].isin(city_record)]["city"].value_counts().keys())
n_counts = list(df[df['city'].isin(city_record)]["city"].value_counts().values)
print(city)
print(n_counts)
# Out:
# ['Bangalore', 'Ahmedabad', 'Hyderabad']
# [683, 249, 239]

# %%
import matplotlib.pyplot as plt

# %%
myexplode = [0, 0.1, 0.2]
plt.pie(n_counts,labels=city,explode=myexplode,autopct="%2.2f%%",shadow=True,wedgeprops={"edgecolor":"k","linewidth":2})
plt.title("city distribution",fontsize=15,color="blue")
plt.show()

# %%
brands_name = list(df2['brand'].value_counts().keys())
no_of_bikes = list(df2['brand'].value_counts().values)
print(brands_name)
print(no_of_bikes)
# Out:
# ['Bajaj', 'Royal Enfield', 'Hero', 'Honda', 'Yamaha', 'TVS', 'KTM', 'Suzuki', 'Harley-Davidson', 'Kawasaki', 'Hyosung', 'Mahindra', 'Benelli', 'Triumph', 'Ducati', 'BMW']
# [2081, 1346, 1142, 676, 651, 481, 375, 203, 91, 61, 53, 50, 46, 21, 20, 10]

# %%
plt.figure(figsize=(18,8))
plt.bar(brands_name,no_of_bikes,color="g",ec="black")
plt.title("available bike brands")
plt.ylabel("No of counts")
plt.xlabel("Brands name ")
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(18,8))
plt.barh(brands_name,no_of_bikes,color="g",ec="black")
plt.title("available bike brands")
plt.ylabel("No of counts")
plt.xlabel("Brands name ")
plt.xticks(rotation=90)
plt.show()

# %%
df
# Out:
#                                  bike_name     price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1              Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                     Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                     TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                    ...       ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc   25000.0      Delhi     48587.0
# 9369                   Bajaj Avenger 220cc   35000.0  Bangalore     60000.0
# 9370        Harley-Davidson Street 750 ABS  450000.0    Jodhpur      3430.0
# 9371                 Bajaj Dominar 400 ABS  139000.0  Hyderabad     21300.0
# 9372              Bajaj Avenger Street 220   80000.0  Hyderabad      7127.0
#
#             owner  age  power            brand
# ...

# %%
# scatter plot   (numerical_x,numerical_y) 
x = [10,15,36]
y = [5,9,7] 
plt.scatter(x,y)
plt.show()

# %%
plt.scatter(df2['age'],df2['price'])
plt.xlabel("Age")
plt.ylabel("price")
plt.title("relationship btwn price & age")
plt.show()

# %%
df2.head()
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#          owner  age  power          brand
# 0  First Owner  3.0  110.0            TVS
# 1  First Owner  4.0  350.0  Royal Enfield
# 2  First Owner  8.0  675.0        Triumph
# 3  First Owner  4.0  180.0            TVS
# 4  First Owner  3.0  150.0         Yamaha

# %%
df2
# Out:
#                                  bike_name     price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1              Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                     Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                     TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                    ...       ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc   25000.0      Delhi     48587.0
# 9369                   Bajaj Avenger 220cc   35000.0  Bangalore     60000.0
# 9370        Harley-Davidson Street 750 ABS  450000.0    Jodhpur      3430.0
# 9371                 Bajaj Dominar 400 ABS  139000.0  Hyderabad     21300.0
# 9372              Bajaj Avenger Street 220   80000.0  Hyderabad      7127.0
#
#             owner  age  power            brand
# ...

# %%
df['owner'].value_counts().keys()
# Out:
# Index(['First Owner', 'Second Owner', 'Third Owner', 'Fourth Owner Or More'], dtype='object', name='owner')

# %%
owner_maping_dict = {'First Owner':1, 'Second Owner':2, 'Third Owner':3, 'Fourth Owner Or More':4}
df2['owner'] = df2['owner'].map(owner_maping_dict)
# Out:
# C:\Users\Ranjit\AppData\Local\Temp\ipykernel_14168\1422386119.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['owner'] = df2['owner'].map(owner_maping_dict)

# %%
df2.head()
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#    owner  age  power          brand
# 0      1  3.0  110.0            TVS
# 1      1  4.0  350.0  Royal Enfield
# 2      1  8.0  675.0        Triumph
# 3      1  4.0  180.0            TVS
# 4      1  3.0  150.0         Yamaha

# %%
df2.drop(['bike_name','city'],axis=1,inplace=True)
# Out:
# C:\Users\Ranjit\AppData\Local\Temp\ipykernel_14168\1642961446.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.drop(['bike_name','city'],axis=1,inplace=True)

# %%
df2.head()
# Out:
#       price  kms_driven  owner  age  power          brand
# 0   35000.0     17654.0      1  3.0  110.0            TVS
# 1  119900.0     11000.0      1  4.0  350.0  Royal Enfield
# 2  600000.0       110.0      1  8.0  675.0        Triumph
# 3   65000.0     16329.0      1  4.0  180.0            TVS
# 4   80000.0     10000.0      1  3.0  150.0         Yamaha

# %%
df2['brand'].nunique()
# Out:
# 16

# %%
df2['brand'].unique()
# Out:
# array(['TVS', 'Royal Enfield', 'Triumph', 'Yamaha', 'Honda', 'Hero',
#        'Bajaj', 'Suzuki', 'Benelli', 'KTM', 'Mahindra', 'Kawasaki',
#        'Ducati', 'Hyosung', 'Harley-Davidson', 'BMW'], dtype=object)

# %%
brands_maping_dict = {'TVS':1, 'Royal Enfield':2, 'Triumph':3, 'Yamaha':4, 'Honda':5, 'Hero':6,
       'Bajaj':7, 'Suzuki':8, 'Benelli':9, 'KTM':10, 'Mahindra':11, 'Kawasaki':12,
       'Ducati':13, 'Hyosung':14, 'Harley-Davidson':15, 'BMW':16}
df2['brand'] = df2['brand'].map(brands_maping_dict)
# Out:
# C:\Users\Ranjit\AppData\Local\Temp\ipykernel_14168\2454342172.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['brand'] = df2['brand'].map(brands_maping_dict)

# %%
df2.head()
# Out:
#       price  kms_driven  owner  age  power  brand
# 0   35000.0     17654.0      1  3.0  110.0      1
# 1  119900.0     11000.0      1  4.0  350.0      2
# 2  600000.0       110.0      1  8.0  675.0      3
# 3   65000.0     16329.0      1  4.0  180.0      1
# 4   80000.0     10000.0      1  3.0  150.0      4

# %%
df2.dtypes
# Out:
# price         float64
# kms_driven    float64
# owner           int64
# age           float64
# power         float64
# brand           int64
# dtype: object

# %%
df2.isnull().sum()
# Out:
# price         0
# kms_driven    0
# owner         0
# age           0
# power         0
# brand         0
# dtype: int64

# %%
df2.head()  # clean or process
# Out:
#       price  kms_driven  owner  age  power  brand
# 0   35000.0     17654.0      1  3.0  110.0      1
# 1  119900.0     11000.0      1  4.0  350.0      2
# 2  600000.0       110.0      1  8.0  675.0      3
# 3   65000.0     16329.0      1  4.0  180.0      1
# 4   80000.0     10000.0      1  3.0  150.0      4

# %%
# x and  y variable 
x = df2.drop(['price'],axis=1)

# %%
x.head()
# Out:
#    kms_driven  owner  age  power  brand
# 0     17654.0      1  3.0  110.0      1
# 1     11000.0      1  4.0  350.0      2
# 2       110.0      1  8.0  675.0      3
# 3     16329.0      1  4.0  180.0      1
# 4     10000.0      1  3.0  150.0      4

# %%
y = df2[['price']]

# %%
x.shape[0] * 0.8
# Out:
# 5845.6

# %%
pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Train test split data

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test =   train_test_split(x,y,train_size=0.8)

# %%
from sklearn.linear_model import LinearRegression 
from sklearn.ensemble import RandomForestRegressor

# %%
# create objects of a classes 
lnr = LinearRegression()
rdf = RandomForestRegressor()

# %%
### 
lnr.fit(x_train,y_train)  # train purpose
# Out:
# LinearRegression()

# %%
rdf.fit(x_train,y_train)
# Out:
# c:\Users\Ranjit\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegressor()

# %%
### performance 
print("Linear Regression  : ",lnr.score(x_train,y_train) * 100)
print("RandomForest Regression  : ",rdf.score(x_train,y_train) * 100)
# Out:
# Linear Regression  :  71.74921392219578
# RandomForest Regression  :  98.73439653417235

# %%
# prediction 

x_test.shape
# Out:
# (1462, 5)

# %%
x_test.head()
# Out:
#       kms_driven  owner   age  power  brand
# 7384     21890.0      1   8.0  200.0      7
# 4968     13328.0      1   4.0  100.0      6
# 8273     47970.0      1  16.0  150.0      7
# 3300     20000.0      1   5.0  500.0      2
# 761      48000.0      1  12.0  500.0      2

# %%
y_pred = rdf.predict(x_test)

# %%
y_pred.shape
# Out:
# (1462,)

# %%
y_pred
# Out:
# array([45667.28, 35826.39, 12903.82, ..., 21020.  , 26419.98, 27773.  ])

# %%
x_test.head()
# Out:
#       kms_driven  owner   age  power  brand
# 7384     21890.0      1   8.0  200.0      7
# 4968     13328.0      1   4.0  100.0      6
# 8273     47970.0      1  16.0  150.0      7
# 3300     20000.0      1   5.0  500.0      2
# 761      48000.0      1  12.0  500.0      2

# %%
x_test["actual_price"]  = y_test['price']

# %%
x_test.head()
# Out:
#       kms_driven  owner   age  power  brand  actual_price
# 7384     21890.0      1   8.0  200.0      7       53500.0
# 4968     13328.0      1   4.0  100.0      6       35000.0
# 8273     47970.0      1  16.0  150.0      7       10800.0
# 3300     20000.0      1   5.0  500.0      2      125000.0
# 761      48000.0      1  12.0  500.0      2      100000.0

# %%
x_test["predicted_price"] = y_pred

# %%
x_test.head(40)
# Out:
#       kms_driven  owner   age  power  brand  actual_price  predicted_price
# 7384     21890.0      1   8.0  200.0      7       53500.0     45667.280000
# 4968     13328.0      1   4.0  100.0      6       35000.0     35826.390000
# 8273     47970.0      1  16.0  150.0      7       10800.0     12903.820000
# 3300     20000.0      1   5.0  500.0      2      125000.0    110902.000000
# 761      48000.0      1  12.0  500.0      2      100000.0     77073.000000
# 1273     23500.0      1   4.0  150.0      5       90000.0     91970.000000
# 6931      5989.0      1   4.0  650.0     12      500000.0    517502.000000
# 3483     24000.0      1   5.0  220.0      7       74000.0     62895.000000
# 5608     30000.0      1  10.0  150.0      7       25000.0     23848.000000
# 2405      2412.0      1   4.0  400.0      7      160000.0    163249.220000
# 5829     38000.0      1   7.0  250.0      5       85000.0     77482.990000
# ...

# %%
x_test.to_csv("predictionMl_model.csv",index=False)

# %%
x_test[['kms_driven', 'owner', 'age', 'power', 'brand', ]]
# Out:
#       kms_driven  owner   age  power  brand
# 7384     21890.0      1   8.0  200.0      7
# 4968     13328.0      1   4.0  100.0      6
# 8273     47970.0      1  16.0  150.0      7
# 3300     20000.0      1   5.0  500.0      2
# 761      48000.0      1  12.0  500.0      2
# ...          ...    ...   ...    ...    ...
# 5865     32000.0      1   7.0  135.0      7
# 8028     33000.0      1  10.0  100.0      6
# 1257     67614.0      1  10.0  125.0      8
# 1336     22000.0      1   7.0  150.0      7
# 7557     48000.0      2   8.0  125.0      5
#
# [1462 rows x 5 columns]

# %%
rdf.score(x_test[['kms_driven', 'owner', 'age', 'power', 'brand', ]],y_test)
# Out:
# 0.8861391725158001

# %%
lnr.score(x_test[['kms_driven', 'owner', 'age', 'power', 'brand', ]],y_test)
# Out:
# 0.7074287267176125

# %%
import warnings 
warnings.filterwarnings("ignore")

# %%
print(round(list(rdf.predict([[1500,1,2,120,2]]))[0]))
# Out:
# 55557

# %%
df2.shape
# Out:
# (7307, 6)

# %%
x_train.head()
# Out:
#       kms_driven  owner   age  power  brand
# 2552     18096.0      1   5.0  220.0      7
# 868      28000.0      1   8.0  125.0      7
# 5832     30000.0      1  12.0  100.0      7
# 9200     25000.0      1   8.0  150.0      5
# 5571      7983.0      1   5.0  200.0      7

# %%
x_test.head()
# Out:
#       kms_driven  owner   age  power  brand  actual_price  predicted_price
# 7384     21890.0      1   8.0  200.0      7       53500.0         45667.28
# 4968     13328.0      1   4.0  100.0      6       35000.0         35826.39
# 8273     47970.0      1  16.0  150.0      7       10800.0         12903.82
# 3300     20000.0      1   5.0  500.0      2      125000.0        110902.00
# 761      48000.0      1  12.0  500.0      2      100000.0         77073.00
