# %%
import pandas as pd 
df = pd.read_csv(r"Used_Bikes_data.csv")

# %%
df.head()
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#          owner  age  power          brand
# 0  First Owner  3.0  110.0            TVS
# 1  First Owner  4.0  350.0  Royal Enfield
# 2  First Owner  8.0  675.0        Triumph
# 3  First Owner  4.0  180.0            TVS
# 4  First Owner  3.0  150.0         Yamaha

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32648 entries, 0 to 32647
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   bike_name   32648 non-null  object
#  1   price       32648 non-null  float64
#  2   city        32648 non-null  object
#  3   kms_driven  32648 non-null  float64
#  4   owner       32648 non-null  object
#  5   age         32648 non-null  float64
#  6   power       32648 non-null  float64
#  7   brand       32648 non-null  object
# dtypes: float64(4), object(4)
# memory usage: 2.0+ MB

# %%
df.duplicated().sum()
# Out:
# 25324

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (7324, 8)

# %%
df.head()
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#          owner  age  power          brand
# 0  First Owner  3.0  110.0            TVS
# 1  First Owner  4.0  350.0  Royal Enfield
# 2  First Owner  8.0  675.0        Triumph
# 3  First Owner  4.0  180.0            TVS
# 4  First Owner  3.0  150.0         Yamaha

# %%
delhi = df[(df['city'] == "Delhi") & (df['brand']=="Royal Enfield")]
delhi.shape
# Out:
# (305, 8)

# %%
df["brand"].value_counts().keys()
# Out:
# Index(['Bajaj', 'Royal Enfield', 'Hero', 'Honda', 'Yamaha', 'TVS', 'KTM',
#        'Suzuki', 'Harley-Davidson', 'Kawasaki', 'Hyosung', 'Mahindra',
#        'Benelli', 'Triumph', 'Ducati', 'BMW', 'Jawa', 'Indian', 'MV',
#        'Rajdoot', 'LML', 'Yezdi', 'Ideal'],
#       dtype='object', name='brand')

# %%
brands = ['Bajaj', 'Royal Enfield', 'Hero', 'Honda', 'Yamaha', 'TVS', 'KTM',
       'Suzuki', 'Harley-Davidson', 'Kawasaki', 'Hyosung', 'Mahindra',
       'Benelli', 'Triumph', 'Ducati', 'BMW']

df2 = df[df['brand'].isin(brands)]
df2.head()
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#          owner  age  power          brand
# 0  First Owner  3.0  110.0            TVS
# 1  First Owner  4.0  350.0  Royal Enfield
# 2  First Owner  8.0  675.0        Triumph
# 3  First Owner  4.0  180.0            TVS
# 4  First Owner  3.0  150.0         Yamaha

# %%
df['brand'].nunique()
# Out:
# 23

# %%
df2['city'].nunique()
# Out:
# 443

# %%
df2['city'].unique()
# Out:
# array(['Ahmedabad', 'Delhi', 'Bangalore', 'Mumbai', 'Kalyan', 'Faridabad',
#        'Mettur', 'Hyderabad', 'Kaithal', 'Gurgaon', 'Pune', 'Noida',
#        'Nashik', 'Kochi', 'Allahabad', 'Samastipur', 'Nadiad', 'Lucknow',
#        'Jaipur', 'Karnal', 'Gorakhpur', 'Vidisha', 'Hosur', 'Bagalkot',
#        'Baripara', 'Agra', 'Dharwad', 'Vadodara', 'Jalandhar', 'Surat',
#        'Chennai', 'Navi Mumbai', 'Gandhidham', 'Visakhapatnam',
#        'Thrissur', 'Kolkata', 'Ernakulam', 'Barasat', 'Ghaziabad',
#        'Bhubaneshwar', 'Amritsar', 'Bhopal', 'Hamirpur(hp)', 'Kottayam',
#        'Arrah', 'Patiala', 'Ranga Reddy', 'Mandi', 'Ludhiana', 'Mandya',
#        'Siliguri', 'Aurangabad', 'Kanpur', 'Bhilwara', 'Meerut', 'Rewari',
#        'Ahmednagar', 'Wardha', 'Chandigarh', 'Ranchi', 'Panvel', 'Thane',
#        'Jabalpur', 'Kota', 'Rohtak', 'Rajkot', 'Varanasi', '24 Pargana',
#        'Banka', 'Nagpur', 'Banki', 'Pali', 'Chhatarpur', 'Katihar',
# ...

# %%
df["owner"].value_counts()
# Out:
# owner
# First Owner             6642
# Second Owner             588
# Third Owner               84
# Fourth Owner Or More      10
# Name: count, dtype: int64

# %%
delhi['price'].min()
# Out:
# 33500.0

# %%
delhi[delhi['price'] == delhi['price'].min()]
# Out:
#                             bike_name    price   city  kms_driven  \
# 5811  Royal Enfield Thunderbird 350cc  33500.0  Delhi     49463.0
#
#             owner   age  power          brand
# 5811  First Owner  16.0  350.0  Royal Enfield

# %%
delhi["owner"].value_counts()
# Out:
# owner
# First Owner             268
# Second Owner             33
# Fourth Owner Or More      2
# Third Owner               2
# Name: count, dtype: int64

# %%
test = delhi[delhi['price'] <= delhi['price'].mean()]
test.head()
# Out:
#                                     bike_name    price   city  kms_driven  \
# 9    Royal Enfield Classic Desert Storm 500cc  88000.0  Delhi     19000.0
# 44                Royal Enfield Classic 350cc  85000.0  Delhi     18000.0
# 51                Royal Enfield‎ Bullet 350cc  90000.0  Delhi     15300.0
# 64            Royal Enfield Thunderbird 350cc  88000.0  Delhi     19000.0
# 126               Royal Enfield Classic 350cc  92500.0  Delhi     11000.0
#
#             owner  age  power          brand
# 9    Second Owner  7.0  500.0  Royal Enfield
# 44    First Owner  6.0  350.0  Royal Enfield
# 51    First Owner  7.0  350.0  Royal Enfield
# 64    First Owner  5.0  350.0  Royal Enfield
# 126   First Owner  6.0  350.0  Royal Enfield

# %%
test['owner'].value_counts()
# Out:
# owner
# First Owner             135
# Second Owner             29
# Fourth Owner Or More      2
# Third Owner               2
# Name: count, dtype: int64

# %%
# pip install matplotlib

# %%
df.head()
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#          owner  age  power          brand
# 0  First Owner  3.0  110.0            TVS
# 1  First Owner  4.0  350.0  Royal Enfield
# 2  First Owner  8.0  675.0        Triumph
# 3  First Owner  4.0  180.0            TVS
# 4  First Owner  3.0  150.0         Yamaha

# %%
city_record = ['Ahmedabad', 'Bangalore' , 'Hyderabad' ]
df[df['city'].isin(city_record)]["city"].value_counts()
# Out:
# city
# Bangalore    683
# Ahmedabad    249
# Hyderabad    239
# Name: count, dtype: int64

# %%
city = list(df[df['city'].isin(city_record)]["city"].value_counts().keys())
n_counts = list(df[df['city'].isin(city_record)]["city"].value_counts().values)
print(city)
print(n_counts)
# Out:
# ['Bangalore', 'Ahmedabad', 'Hyderabad']
# [683, 249, 239]

# %%
import matplotlib.pyplot as plt

# %%
myexplode = [0, 0.3, 0.2]
plt.pie(n_counts,labels=city,explode=myexplode)
plt.show()
