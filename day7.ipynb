# %%
print("hiii")
# Out:
# hiii

# %%
pip3 install pandas

# %%
import pandas as pd 
print("imported")
# Out:
# imported

# %%
student_data = {"name":['claude','jack','teddy'],
                "age":[24,26,25],
                "city":["agra","mummai","goa"]}
print(student_data)
print(type(student_data))
# Out:
# {'name': ['claude', 'jack', 'teddy'], 'age': [24, 26, 25], 'city': ['agra', 'mummai', 'goa']}
# <class 'dict'>

# %%
1. series 
2. dataframe

# %%
df = pd.DataFrame(student_data)

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
ser = df["name"]

# %%
ser
# Out:
# 0    claude
# 1      jack
# 2     teddy
# Name: name, dtype: object

# %%
df
# Out:
#      name  age    city
# 0  claude   24    agra
# 1    jack   26  mummai
# 2   teddy   25     goa

# %%
print(type(ser))
# Out:
# <class 'pandas.core.series.Series'>

# %%
df.name  # df["name"]
# Out:
# 0    claude
# 1      jack
# 2     teddy
# Name: name, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    3 non-null      object
#  1   age     3 non-null      int64
#  2   city    3 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 204.0+ bytes

# %%
df.dtypes
# Out:
# name    object
# age      int64
# city    object
# dtype: object

# %%
df.columns
# Out:
# Index(['name', 'age', 'city'], dtype='object')

# %%
df.shape   # (rows, columns)
# Out:
# (3, 3)

# %%
df
# Out:
#      name  age    city
# 0  claude   24    agra
# 1    jack   26  mummai
# 2   teddy   25     goa

# %%
df[["age","name"]]
# Out:
#    age    name
# 0   24  claude
# 1   26    jack
# 2   25   teddy

# %%
df
# Out:
#      name  age    city
# 0  claude   24    agra
# 1    jack   26  mummai
# 2   teddy   25     goa

# %%
# loc and iloc 
df.iloc[1]
# Out:
# name      jack
# age         26
# city    mummai
# Name: 1, dtype: object
