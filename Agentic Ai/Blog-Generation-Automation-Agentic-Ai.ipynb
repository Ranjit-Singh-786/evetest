# %% [markdown]
# #### Multi-Agentic-Ai System based Blog Generator
# <p>
# This project is a multi-agent Agentic AI system built using LangGraph, where multiple AI agents collaborate to complete a task.
# The system includes a Planner Agent, Research Agent (with RAG tool), and Writer Agent, all connected through a stateful graph workflow.
# Each agent performs a specific role and updates a shared state, enabling structured execution from planning to final output generation.
# </p>

# %%
## First Understand Basics
from typing import TypedDict

class AgentState(TypedDict):
    topic: str
    plan: str
    research: str
    blog: str

# %%
AgentState.__annotations__ 
# to initialize a dictionary, where agents will maintain the state
# Out:
# {'topic': str, 'plan': str, 'research': str, 'blog': str}

# %%
from langgraph.graph import StateGraph, END
from typing import TypedDict
from langchain_openai import ChatOpenAI
from langchain_community.vectorstores import FAISS
from langchain_openai import OpenAIEmbeddings

# ------------------ STATE ------------------
class AgentState(TypedDict):
    topic: str
    plan: str
    research: str
    blog: str


llm = ChatOpenAI(model="gpt-4o-mini")

# ------------------ TOOL (RAG as tool) ------------------
def create_vector_store():
    docs = [
        "AI in healthcare improves diagnosis and treatment.",
        "Machine learning helps in detecting diseases early.",
        "DSA is a very important for software development,",
        "Mathmatics Geometric formula"
      
    ]
    embeddings = OpenAIEmbeddings()
    return FAISS.from_texts(docs, embeddings)

vector_store = create_vector_store()


# ------------------ NODES ------------------

# 1. Planner Agent
def planner(state: AgentState):
    response = llm.invoke(f"Create a step-by-step research plan for: {state['topic']}")
    return {"plan": response.content}


# 2. Research Agent (USES TOOL 🔥)
def researcher(state: AgentState):
    docs = vector_store.similarity_search(state["topic"], k=2)
    context = "\n".join([d.page_content for d in docs])

    response = llm.invoke(f"""
Use this context to research:

{context}

Follow this plan:
{state['plan']}
""")
    return {"research": response.content}


# 3. Writer Agent
def writer(state: AgentState):
    response = llm.invoke(f"""
Write a structured blog using this research:

{state['research']}
""")
    return {"blog": response.content}


# ------------------ GRAPH ------------------

builder = StateGraph(AgentState)

builder.add_node("planner", planner)
builder.add_node("researcher", researcher)
builder.add_node("writer", writer)

builder.set_entry_point("planner")

builder.add_edge("planner", "researcher")
builder.add_edge("researcher", "writer")
builder.add_edge("writer", END)

graph = builder.compile()

# ------------------ RUN ------------------

result = graph.invoke({"topic": "AI in healthcare"})

print("\n--- FINAL BLOG ---\n")
print(result["blog"])
# Out:
# --- FINAL BLOG ---
#
# # Exploring the Role of AI in Healthcare: A Comprehensive Research Plan
#
# Artificial Intelligence (AI) is transforming the landscape of healthcare, offering new solutions for diagnosis, treatment personalization, and operational efficiencies. However, navigating this complex integration requires a structured approach to research that can yield actionable insights. Below, we outline a detailed research plan aimed at exploring the implications of AI in healthcare, aligned with both current trends and future opportunities.
#
# ## Step 1: Define Research Objectives
#
# ### Identify Specific Research Questions
# To lay a solid foundation, we must identify key questions:
# - What are the current applications of AI in healthcare, particularly in diagnostics, treatment personalization, and patient monitoring?
# - How does AI contribute to improved patient outcomes, focusing on disease detection and treatment efficacy?
# - What barriers and limitations arise when integrating AI technologies into healthcare settings?
# - How does the adoption of AI influence healthcare costs and operational efficiencies?
#
# ### Set Scope and Goals
# This research will monitor specific domains within healthcare, such as diagnostic processes, treatment planning, and operational efficiencies in hospital workflows. The ultimate goal is to assess both technological advancements and their practical implications in real-world healthcare scenarios.
#
# ## Step 2: Conduct a Literature Review
#
# ### Gather Existing Research
# An extensive literature review will involve:
# - Sourcing academic articles from relevant databases including PubMed, IEEE Xplore, and Google Scholar.
# - Reviewing white papers and reports from trusted organizations like McKinsey and the World Health Organization, which outline AI innovations in the healthcare sector.
#
# ### Summarize Key Findings
# All collected data will be compiled to:
# - Document existing AI models and frameworks within healthcare.
# - Highlight successful implementation patterns, along with the limitations faced by various studies.
#
# ## Step 3: Develop a Research Design
#
# ### Choose Research Methodology
# A mixed-method approach will be adopted:
# - Qualitative analysis through interviews with healthcare professionals to extract insights.
# - Quantitative analysis to gauge the impact of AI applications through surveys.
#
# ### Select Data Sources
# Data will be sourced from:
# - Electronic health records (EHR), patient demographic datasets, and existing research data.
# - Original data collection as needed, complemented by surveys or focus groups.
#
# ## Step 4: Data Collection
#
# ### Collect Primary Data
# To gather firsthand information:
# - Structured surveys targeting healthcare professionals and patients will be created to understand user experiences with AI.
# - Focus groups or interviews will provide qualitative insights regarding AI efficacy and the challenges faced.
#
# ### Gather Secondary Data
# Secondary data will consist of:
# - Findings from pilot studies on AI applications.
# - Existing systematic reviews and efficiency reports documenting the impacts of AI solutions in healthcare.
#
# ## Step 5: Data Analysis
#
# ### Choose Analysis Techniques
# The analysis will utilize:
# - Statistical software (SPSS, R, Python) for quantitative data.
# - Thematic analysis for qualitative data from interviews and open-ended survey responses.
#
# ### Interpret Results
# The findings will be synthesized to assess:
# - The extent to which AI improves health outcomes and reduces costs.
# - Identification of barriers to adoption and areas needing further exploration.
#
# ## Step 6: Address Ethical Considerations
#
# ### Ensure Compliance
# Compliance with ethical guidelines is paramount:
# - Securing Institutional Review Board (IRB) approvals will be essential when working with patient data.
# - Maintaining patient anonymity and confidentiality throughout the research process.
#
# ### Consider Bias and Fairness
# The research will also:
# - Investigate possible biases in AI algorithms that could exacerbate health disparities.
# - Advocate for inclusivity in the development of AI technologies.
#
# ## Step 7: Document Findings
#
# ### Write the Research Paper
# The findings will be organized systematically:
# - Sections will include Introduction, Literature Review, Methodology, Results, Discussion, and Conclusion.
# - Visual aids such as charts and graphs will be incorporated to enhance clarity.
#
# ### Prepare for Publication
# Identifying suitable journals or conferences relevant to healthcare and AI will be crucial. Adhering to their formatting and submission guidelines will ensure proper dissemination of our findings.
#
# ## Step 8: Disseminate Results
#
# ### Present Findings
# To ensure our findings reach diverse audiences:
# - Prepare engaging presentations for conferences focused on key insights and action items.
# - Develop infographics and summary reports for easy dissemination among healthcare providers and policymakers.
#
# ### Engage with Stakeholders
# Conducting presentations for healthcare organizations and technology developers will advocate for informed decision-making within the sector.
#
# ## Step 9: Plan for Future Research
#
# ### Identify Areas for Further Study
# Post-research, we will highlight areas needing more exploration based on identified gaps:
# - Examining AI effects on specific populations or diseases not covered in the initial study.
#
# ### Create a Research Roadmap
# A meticulous roadmap will outline:
# - Project timelines, potential funding sources, and collaborative strategies with healthcare institutions and technology firms.
#
# ## Step 10: Review and Reflection
#
# ### Evaluate Process
# Finally, we will assess the overall research methodology's effectiveness in addressing the original questions posed. Feedback from mentors and peers will be integrated to enhance future research.
#
# ### Identify Improvements
# Documenting lessons learned will be essential for refining future methodologies, ensuring continuous improvement in our research ventures.
#
# ---
#
# By implementing this structured research plan, we aim to systematically explore the multifaceted role of AI in healthcare, ultimately contributing valuable insights to this rapidly evolving field. Through meticulous investigation and open dissemination, our findings will support the ongoing discourse and enhance the practical applications of AI in healthcare.

# %% [markdown]
# ### Thank You
